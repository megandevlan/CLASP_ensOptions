# %%
# Load libraries

# # Plotting utils 
import datetime
import glob
import os
import pickle
# Analysis
import time
import warnings
from datetime import date, timedelta

import matplotlib as matplotlib
import matplotlib.animation as animation
import matplotlib.colors as colors
import matplotlib.dates as mdates
import matplotlib.patches as patches
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import metpy.calc as mpc
import numpy as np
import pandas as pd
import scipy.stats as stats
import xarray as xr
from matplotlib.dates import DateFormatter
from metpy.plots import Hodograph, SkewT
from metpy.units import units
from mpl_toolkits.axes_grid1 import make_axes_locatable

import seaborn as sns
warnings.filterwarnings('ignore')

# %%
hmgDir = '/glade/scratch/mdfowler/archive/FSCAM.T42_T42.CLASP_SAS.HMG.001/'
htgDir = '/glade/scratch/mdfowler/archive/FSCAM.T42_T42.CLASP_SAS.HTG.001/'

atmFile_hmg = hmgDir+'/atm/hist/'+'FSCAM.T42_T42.CLASP_SAS.HMG.001.cam.h0.2013-06-10-43200.nc'
atmFile_htg = htgDir+'/atm/hist/'+'FSCAM.T42_T42.CLASP_SAS.HTG.001.cam.h0.2013-06-10-43200.nc'

hmgDS = xr.open_dataset(atmFile_hmg, decode_times=True)
htgDS = xr.open_dataset(atmFile_htg, decode_times=True) 


lndFile_hmg = hmgDir+'/lnd/hist/'+'FSCAM.T42_T42.CLASP_SAS.HMG.001.clm2.h0.2013-06-10-43200.nc'
lndFile_htg = htgDir+'/lnd/hist/'+'FSCAM.T42_T42.CLASP_SAS.HTG.001.clm2.h0.2013-06-10-43200.nc'

hmgDS_clm = xr.open_dataset(lndFile_hmg, decode_times=True)
htgDS_clm = xr.open_dataset(lndFile_htg, decode_times=True)

# %%
plt.plot(hmgDS.time.values, np.squeeze(hmgDS.PBLH.values), label='HMG')
plt.plot(htgDS.time.values, np.squeeze(htgDS.PBLH.values), label='HTG')
plt.legend()
plt.title('PBLH')
# Out:
# Text(0.5, 1.0, 'PBLH')

# %%
plt.plot(hmgDS.time.values, np.squeeze(hmgDS.THLP2_CLUBB.isel(ilev=-1).values), label='HMG')
plt.plot(htgDS.time.values, np.squeeze(htgDS.THLP2_CLUBB.isel(ilev=-1).values), label='HTG')
plt.legend()
plt.title('THLP2_CLUBB (ilev=-1')
# Out:
# Text(0.5, 1.0, 'THLP2_CLUBB (ilev=-1')

# %%
plt.plot(hmgDS.time.values, np.squeeze(hmgDS.RTP2_CLUBB.isel(ilev=-1).values), label='HMG')
plt.plot(htgDS.time.values, np.squeeze(htgDS.RTP2_CLUBB.isel(ilev=-1).values), label='HTG')
plt.legend()
plt.title('RTP2_CLUBB (ilev=-1')
# Out:
# Text(0.5, 1.0, 'RTP2_CLUBB (ilev=-1')

# %%
plt.plot(hmgDS.time.values, np.squeeze(hmgDS.T.isel(lev=-1).values), label='HMG')
plt.plot(htgDS.time.values, np.squeeze(htgDS.T.isel(lev=-1).values), label='HTG')
plt.legend()
plt.title('T (lev=-1')
# Out:
# Text(0.5, 1.0, 'T (lev=-1')

# %%
plt.plot(hmgDS.time.values, np.squeeze(hmgDS.Q.isel(lev=-1).values), label='HMG')
plt.plot(htgDS.time.values, np.squeeze(htgDS.Q.isel(lev=-1).values), label='HTG')
plt.legend()
plt.title('Q (lev=-1')
# Out:
# Text(0.5, 1.0, 'Q (lev=-1')

# %%
plt.plot(hmgDS.time.values, np.squeeze(hmgDS.TMQ.values), label='HMG')
plt.plot(htgDS.time.values, np.squeeze(htgDS.TMQ.values), label='HTG')
plt.legend()
plt.title('TMQ')
# Out:
# Text(0.5, 1.0, 'TMQ')

# %%
plt.plot(hmgDS.time.values, np.squeeze(hmgDS.SHFLX.values), label='HMG')
plt.plot(htgDS.time.values, np.squeeze(htgDS.SHFLX.values), label='HTG')
plt.legend()
plt.title('SHFLX')
# Out:
# Text(0.5, 1.0, 'SHFLX')

# %%
plt.plot(hmgDS.time.values, np.squeeze(hmgDS.LHFLX.values), label='HMG')
plt.plot(htgDS.time.values, np.squeeze(htgDS.LHFLX.values), label='HTG')
plt.legend()
plt.title('LHFLX')
# Out:
# Text(0.5, 1.0, 'LHFLX')

# %%
plt.plot(hmgDS.time.values, np.squeeze(hmgDS.TREFHT.values), label='HMG')
plt.plot(htgDS.time.values, np.squeeze(htgDS.TREFHT.values), label='HTG')
plt.legend()
plt.title('TREFHT')
# Out:
# Text(0.5, 1.0, 'TREFHT')

# %%
plt.plot(hmgDS.time.values, np.squeeze(hmgDS.QREFHT.values), label='HMG')
plt.plot(htgDS.time.values, np.squeeze(htgDS.QREFHT.values), label='HTG')
plt.legend()
plt.title('QREFHT')
# Out:
# Text(0.5, 1.0, 'QREFHT')

# %%
plt.plot(hmgDS_clm.time.values, np.squeeze(hmgDS_clm.SOILWATER_10CM.values), label='HMG')
plt.plot(htgDS_clm.time.values, np.squeeze(htgDS_clm.SOILWATER_10CM.values), label='HTG')
plt.legend()
plt.title('SOILWATER_10CM')
# Out:
# Text(0.5, 1.0, 'SOILWATER_10CM')

# %%
plt.plot(hmgDS_clm.time.values, np.squeeze(hmgDS_clm.FSA.values), label='HMG')
plt.plot(htgDS_clm.time.values, np.squeeze(htgDS_clm.FSA.values), label='HTG')
plt.legend()
plt.title('FSA')
# Out:
# Text(0.5, 1.0, 'FSA')

# %%
plt.plot(hmgDS_clm.time.values, np.squeeze(hmgDS_clm.QVEGE.values), label='HMG')
plt.plot(htgDS_clm.time.values, np.squeeze(htgDS_clm.QVEGE.values), label='HTG')
plt.legend()
plt.title('QVEGE')
# Out:
# Text(0.5, 1.0, 'QVEGE')

# %%
plt.plot(hmgDS_clm.time.values, np.squeeze(hmgDS_clm.QVEGT.values), label='HMG')
plt.plot(htgDS_clm.time.values, np.squeeze(htgDS_clm.QVEGT.values), label='HTG')
plt.legend()
plt.title('QVEGT')
# Out:
# Text(0.5, 1.0, 'QVEGT')

# %%
plt.plot(hmgDS_clm.time.values, np.squeeze(hmgDS_clm.TG.values), label='HMG')
plt.plot(htgDS_clm.time.values, np.squeeze(htgDS_clm.TG.values), label='HTG')
plt.legend()
plt.title('TG')
# Out:
# Text(0.5, 1.0, 'TG')

# %%
plt.plot(hmgDS_clm.time.values, np.squeeze(hmgDS_clm.ZBOT.values), label='HMG')
plt.plot(htgDS_clm.time.values, np.squeeze(htgDS_clm.ZBOT.values), label='HTG')
plt.legend()
plt.title('ZBOT')
# Out:
# Text(0.5, 1.0, 'ZBOT')
